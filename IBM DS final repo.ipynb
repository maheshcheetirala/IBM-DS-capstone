# %%
import pandas as pd
import numpy as np
print("This is Capsotone")
# Out:
# This is Capsotone

# %%
a=np.random.rand(1,50,10)
a
# Out:
# array([[[0.79568877, 0.40845456, 0.10733604, 0.11165469, 0.65829225,
#          0.82906957, 0.30823496, 0.30779856, 0.56717608, 0.01856105],
#         [0.2702914 , 0.22366605, 0.96279425, 0.63610389, 0.40834629,
#          0.79332229, 0.8995248 , 0.90510666, 0.26799901, 0.67858282],
#         [0.82384098, 0.81501278, 0.59319442, 0.69294899, 0.28742545,
#          0.24306753, 0.08031974, 0.91069392, 0.1675706 , 0.37406605],
#         [0.12892988, 0.66404026, 0.28780118, 0.30891054, 0.3048774 ,
#          0.6828427 , 0.877398  , 0.05730946, 0.88465142, 0.02648836],
#         [0.58237252, 0.38038801, 0.83101235, 0.65349314, 0.16230944,
#          0.39117528, 0.31841444, 0.95662083, 0.92096141, 0.94706037],
#         [0.69472705, 0.17584673, 0.52966201, 0.93427373, 0.96459583,
#          0.24572461, 0.07384213, 0.10418789, 0.92236172, 0.75267394],
#         [0.97850598, 0.45610481, 0.07132673, 0.27412847, 0.38426403,
# ...
